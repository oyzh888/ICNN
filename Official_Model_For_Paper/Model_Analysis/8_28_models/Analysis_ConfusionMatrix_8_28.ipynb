# %%
import os, sys
import time
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np

from models_sigmoid import ResNet as resnet_cifar
import pandas as pd
import argparse
import csv
from torch.optim.lr_scheduler import MultiStepLR
from dataLoader import DataLoader

from PIL import Image, ImageDraw

from sklearn.metrics import confusion_matrix, classification_report    # 生成混淆矩阵函数
import matplotlib.pyplot as plt    # 绘图库

print('Init Finished!')
# Out:
# Init Finished!

# %%
args_depth = 20
num_classes = 10
args_dataset = 'cifar-10'
args_batch_size = 512

# %%
# Data Loader
loader = DataLoader(args_dataset,batch_size=args_batch_size)
dataloaders,dataset_sizes = loader.load_data()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def load_model(model_path):
    model = resnet_cifar(depth=args_depth, num_classes=num_classes)
    model = model.cuda()
    model = torch.nn.DataParallel(model)
    model.load_state_dict(torch.load(model_path))
#     print('Successfully Load Model: ', os.path.basename(model_path))
    print('Successfully Load Model: ', model_path)
    return model

# %%
def printF(i, total=100):
    i = int( i / total * 100) + 1
    total = 100
    k = i + 1
    str_ = '>'*i + '' ''*(total-k)
    sys.stdout.write('\r'+str_+'[%s%%]'%(i+1))
    sys.stdout.flush()
    if(i >= total -1): print()

def get_weights(model):
    return model.module.lmask.get_channel_mask()
#     return model.module.lmask.mask

# %%
def predict_model(PATH, title, run_model=True):
    model = load_model(PATH)
    model.train(False)
    use_gpu = True
    epoch = 1
    phase = 'val'
    running_corrects = 0.0
    data_len = len(dataloaders[phase])
    # print(data_len)
    true_labels = []
    model_preds = []
    if run_model:
        for idx,data in enumerate(dataloaders[phase]):
            printF(idx, data_len)
            inputs,labels = data
            if use_gpu:
                inputs = Variable(inputs.cuda())
                labels = Variable(labels.cuda())
            else:
                inputs, labels = Variable(inputs), Variable(labels)
            #forward
            outputs, reg = model(inputs, labels, epoch)
            _, preds = torch.max(outputs.data, 1)
            # _,top5_preds = torch.topk(outputs.data,k=5,dim=1)
            # print ('group loss:',group_loss[0])
            y = labels.data
            batch_size = labels.data.shape[0]
            # print(y.resize_(batch_size,1))
            running_corrects += torch.sum(preds == y)
            # top5_corrects += torch.sum(top5_preds == y.resize_(batch_size,1))
            epoch_acc = float(running_corrects) /dataset_sizes[phase]
            true_labels.extend(y.cpu().numpy())
            model_preds.extend(preds.cpu().numpy())
        print('%s top1 Acc:%.4f'%(phase,epoch_acc))
    
    #Draw weights
    weights = get_weights(model)
    weights = weights.cpu().detach().numpy()
    weights = np.transpose(weights)
#     print(weights.shape)
    fig = plt.figure(figsize=(20,6))
    ax = fig.add_subplot(111)
    im = ax.imshow(weights,cmap=plt.cm.jet)
    plt.colorbar(im,orientation='vertical')
    plt.title(title)
    plt.show()
    return true_labels, model_preds

# %%
labels_name = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
def plot_confusion_matrix(cm, labels_name, title):
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]    # 归一化
    plt.imshow(cm, interpolation='nearest')    # 在特定的窗口上显示图像
    plt.title(title)    # 图像标题
    plt.colorbar()
    num_local = np.array(range(len(labels_name)))    
    plt.xticks(num_local, labels_name, rotation=90)    # 将标签印在x轴坐标上
    plt.yticks(num_local, labels_name)    # 将标签印在y轴坐标上
    plt.ylabel('True label')    
    plt.xlabel('Predicted label')
def plot_confusion_matrix_and_text(cm, labels_name, title):
    plt.figure(figsize=(16,16),dpi=200)
    plt.subplot(221)
    plot_confusion_matrix(cm, labels_name, title)
    plt.subplot(222)
    
    text_img = Image.new('RGB', (350, 250), color = (255,255,255))
    d = ImageDraw.Draw(text_img)
    text_content = classification_report(true_labels, model_preds, target_names=labels_name)
    d.text((0,0), text_content, fill=(0,0,0))
    plt.imshow(text_img)
    plt.show()

# %%
def show_res(PATH, run_model=True):
    model_path = os.path.join(PATH, 'saved_model.pt')
    title = PATH.split('/')[-1]
    true_labels, model_preds = predict_model(model_path, title, run_model)
    cm = confusion_matrix(y_true=true_labels, y_pred=model_preds)
#     plot_confusion_matrix_and_text(cm, labels_name, title)
    plt.show()

# %% [markdown]
# # Algorithm1

# %% [markdown]
# # get_channel_mask show

# %%
def get_weights(model):
    return model.module.lmask.get_channel_mask()
#     return model.module.lmask.mask

# %%
exp_root = '/data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/'
analysis_queue = [
    'TwoStep_Algorithm1_Clip_L11e_3_LimitChannelClass',
    'TwoStep_Algorithm1_Clip_L1_LimitChannelClass',
    'TwoStep_Algorithm1_Clip_L21_LimitChannelClass',
    'TwoStep_Algorithm1_Clip_Lmax_LimitChannelClass',
]
analysis_queue = [exp_root+var for var in analysis_queue]
for item in analysis_queue:
    show_res(item)
# Out:
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/TwoStep_Algorithm1_Clip_L11e_3_LimitChannelClass/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9065
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/TwoStep_Algorithm1_Clip_L1_LimitChannelClass/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9022
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/TwoStep_Algorithm1_Clip_L21_LimitChannelClass/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9062
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/TwoStep_Algorithm1_Clip_Lmax_LimitChannelClass/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9068

# %% [markdown]
# # Show self.mask instead of sigmoid(self.mask)

# %%
def get_weights(model):
#     return model.module.lmask.get_channel_mask()
    return model.module.lmask.mask
exp_root = '/data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/'
analysis_queue = [
    'TwoStep_Algorithm1_Clip_L11e_3_LimitChannelClass',
    'TwoStep_Algorithm1_Clip_L1_LimitChannelClass',
    'TwoStep_Algorithm1_Clip_L21_LimitChannelClass',
    'TwoStep_Algorithm1_Clip_Lmax_LimitChannelClass',
]
analysis_queue = [exp_root+var for var in analysis_queue]
for item in analysis_queue:
    show_res(item)
# Out:
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/TwoStep_Algorithm1_Clip_L11e_3_LimitChannelClass/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9065
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/TwoStep_Algorithm1_Clip_L1_LimitChannelClass/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9022
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/TwoStep_Algorithm1_Clip_L21_LimitChannelClass/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9062
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/TwoStep_Algorithm1_Clip_Lmax_LimitChannelClass/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9068

# %% [markdown]
# # Algorithm2

# %%
def get_weights(model):
    return model.module.lmask.mask
    def get_channel_mask(c_mask):
        delta_scale = 1
        c_mask = torch.sigmoid(c_mask/delta_scale)
        return c_mask
#     return model.module.lmask.get_channel_mask()
    return get_channel_mask(model.module.lmask.mask)

exp_root = '/data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/'
analysis_queue = [
    'TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L1',
    'TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L21',
    'TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_Lmax',
    'TwoStep_Algorithm2_Sigmoid10_L1',
    'TwoStep_Algorithm2_Sigmoid10_Lmax',
    
    'TwoStep_Algorithm2_Sigmoid1e-3_L21',
    'TwoStep_Algorithm2_Sigmoid0.1_L1',
    'TwoStep_Algorithm2_Sigmoid0.1_L12',
]
analysis_queue = [exp_root+var for var in analysis_queue]
for item in analysis_queue:
    show_res(item)
# Out:
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L1/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9078
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L21/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9071
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_Lmax/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9028
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid10_L1/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9068
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid10_Lmax/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9070
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid1e-3_L21/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9030
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid0.1_L1/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9036
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid0.1_L12/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9059

# %%
def get_weights(model):
    return model.module.lmask.get_channel_mask()
#     def get_channel_mask(c_mask):
#         delta_scale = 1
#         c_mask = torch.sigmoid(c_mask/delta_scale)
#         return c_mask
#     return get_channel_mask(model.module.lmask.mask)

exp_root = '/data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/'
analysis_queue = [
    'TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L1',
    'TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L21',
    'TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_Lmax',
    'TwoStep_Algorithm2_Sigmoid10_L1',
    'TwoStep_Algorithm2_Sigmoid10_Lmax',
    
    'TwoStep_Algorithm2_Sigmoid1e-3_L21',
    'TwoStep_Algorithm2_Sigmoid0.1_L1',
    'TwoStep_Algorithm2_Sigmoid0.1_L12',
]
analysis_queue = [exp_root+var for var in analysis_queue]
for item in analysis_queue:
    show_res(item)
# Out:
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L1/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9078
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L21/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9071
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_Lmax/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9028
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid10_L1/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9068
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid10_Lmax/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9070
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid1e-3_L21/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9030
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid0.1_L1/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9036
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid0.1_L12/saved_model.pt
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>[97%]val top1 Acc:0.9059

# %% [markdown]
# # Different Sigmoid Function

# %%
def get_weights(model):
    def get_channel_mask(c_mask):
        delta_scale = 1
        c_mask = torch.sigmoid(c_mask/delta_scale)
        return c_mask
#     return model.module.lmask.get_channel_mask()
    return get_channel_mask(model.module.lmask.mask)

exp_root = '/data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/'
analysis_queue = [
    'TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L1',
    'TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L21',
    'TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_Lmax',
    'TwoStep_Algorithm2_Sigmoid10_L1',
    'TwoStep_Algorithm2_Sigmoid10_Lmax',
    
    'TwoStep_Algorithm2_Sigmoid1e-3_L21',
    'TwoStep_Algorithm2_Sigmoid0.1_L1',
    'TwoStep_Algorithm2_Sigmoid0.1_L12',
]
analysis_queue = [exp_root+var for var in analysis_queue]
for item in analysis_queue:
    show_res(item, run_model = False)
# Out:
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L1/saved_model.pt
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_L21/saved_model.pt
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Alg1Pretrain_Sigmoid10_Lmax/saved_model.pt
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid10_L1/saved_model.pt
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid10_Lmax/saved_model.pt
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid1e-3_L21/saved_model.pt
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid0.1_L1/saved_model.pt
# Successfully Load Model:  /data/ouyangzhihao/Exp/ICNN/LearnableMask/tb_dir/reproduce_8_20/alg2_8_22/TwoStep_Algorithm2_Sigmoid0.1_L12/saved_model.pt

# %% [markdown]
# # Model Weights Analysis

# %%
model_path = analysis_queue[0] + '/saved_model.pt'
model = resnet_cifar(depth=args_depth, num_classes=num_classes)
model = model.cuda()
model = torch.nn.DataParallel(model)
model.load_state_dict(torch.load(model_path))
w = model.module.lmask.get_channel_mask()

# %%
w.shape
# Out:
# torch.Size([64, 10])

# %%
w
# Out:
# tensor([[0.4833, 0.6058, 0.4852, 0.4915, 0.4904, 0.4981, 0.4901, 0.4927, 0.4898,
#          0.5453],
#         [0.4883, 0.6555, 0.4951, 0.4820, 0.4866, 0.4906, 0.4910, 0.4926, 0.5142,
#          0.4861],
#         [0.4830, 0.4770, 0.4763, 0.7230, 0.5087, 0.5246, 0.5226, 0.4595, 0.4838,
#          0.4746],
#         [0.4715, 0.4683, 0.4324, 0.5026, 0.8459, 0.4715, 0.4594, 0.4956, 0.4714,
#          0.4867],
#         [0.4916, 0.4771, 0.4516, 0.4449, 0.5315, 0.4806, 0.8276, 0.4595, 0.4703,
#          0.4618],
#         [0.4866, 0.4917, 0.4831, 0.4887, 0.5034, 0.4913, 0.4987, 0.4924, 0.5714,
#          0.4896],
#         [0.5212, 0.4953, 0.5085, 0.4862, 0.4965, 0.4881, 0.4927, 0.4885, 0.4828,
#          0.4998],
#         [0.4887, 0.4671, 0.8042, 0.4741, 0.4561, 0.5862, 0.4773, 0.4712, 0.4861,
#          0.4694],
#         [0.5658, 0.4880, 0.4854, 0.4736, 0.5197, 0.4807, 0.4899, 0.4763, 0.6149,
#          0.4799],
#         [0.4910, 0.4919, 0.4659, 0.4947, 0.4876, 0.7750, 0.4823, 0.4867, 0.4622,
#          0.4744],
#         [0.4772, 0.6993, 0.4851, 0.4889, 0.5031, 0.4879, 0.4918, 0.4823, 0.4779,
#          0.5341],
#         [0.4965, 0.4992, 0.4841, 0.4848, 0.5002, 0.4976, 0.4920, 0.5401, 0.4919,
#          0.4904],
#         [0.4953, 0.4916, 0.4883, 0.5537, 0.4870, 0.5600, 0.4869, 0.4910, 0.4883,
#          0.4858],
#         [0.4866, 0.4786, 0.4465, 0.4804, 0.4993, 0.6207, 0.4878, 0.5624, 0.5216,
#          0.4929],
#         [0.4939, 0.4879, 0.5032, 0.5120, 0.4849, 0.4848, 0.4895, 0.5116, 0.4892,
#          0.5006],
#         [0.4913, 0.5258, 0.5004, 0.4876, 0.4842, 0.4929, 0.5070, 0.4958, 0.4975,
#          0.4857],
#         [0.5723, 0.4958, 0.4758, 0.4981, 0.5029, 0.4845, 0.4874, 0.4843, 0.5005,
#          0.5023],
#         [0.5165, 0.4855, 0.5675, 0.4715, 0.5011, 0.4719, 0.4930, 0.4932, 0.4882,
#          0.5112],
='cuda:0', grad_fn=<SigmoidBackward>)

# %%
w = model.module.lmask.mask
def get_channel_mask(c_mask):
    delta_scale = 1
    c_mask = torch.sigmoid(c_mask/delta_scale)
    return c_mask
w = get_channel_mask(w)

# %%
w
# Out:
# tensor([[0.4833, 0.6058, 0.4852, 0.4915, 0.4904, 0.4981, 0.4901, 0.4927, 0.4898,
#          0.5453],
#         [0.4883, 0.6555, 0.4951, 0.4820, 0.4866, 0.4906, 0.4910, 0.4926, 0.5142,
#          0.4861],
#         [0.4830, 0.4770, 0.4763, 0.7230, 0.5087, 0.5246, 0.5226, 0.4595, 0.4838,
#          0.4746],
#         [0.4715, 0.4683, 0.4324, 0.5026, 0.8459, 0.4715, 0.4594, 0.4956, 0.4714,
#          0.4867],
#         [0.4916, 0.4771, 0.4516, 0.4449, 0.5315, 0.4806, 0.8276, 0.4595, 0.4703,
#          0.4618],
#         [0.4866, 0.4917, 0.4831, 0.4887, 0.5034, 0.4913, 0.4987, 0.4924, 0.5714,
#          0.4896],
#         [0.5212, 0.4953, 0.5085, 0.4862, 0.4965, 0.4881, 0.4927, 0.4885, 0.4828,
#          0.4998],
#         [0.4887, 0.4671, 0.8042, 0.4741, 0.4561, 0.5862, 0.4773, 0.4712, 0.4861,
#          0.4694],
#         [0.5658, 0.4880, 0.4854, 0.4736, 0.5197, 0.4807, 0.4899, 0.4763, 0.6149,
#          0.4799],
#         [0.4910, 0.4919, 0.4659, 0.4947, 0.4876, 0.7750, 0.4823, 0.4867, 0.4622,
#          0.4744],
#         [0.4772, 0.6993, 0.4851, 0.4889, 0.5031, 0.4879, 0.4918, 0.4823, 0.4779,
#          0.5341],
#         [0.4965, 0.4992, 0.4841, 0.4848, 0.5002, 0.4976, 0.4920, 0.5401, 0.4919,
#          0.4904],
#         [0.4953, 0.4916, 0.4883, 0.5537, 0.4870, 0.5600, 0.4869, 0.4910, 0.4883,
#          0.4858],
#         [0.4866, 0.4786, 0.4465, 0.4804, 0.4993, 0.6207, 0.4878, 0.5624, 0.5216,
#          0.4929],
#         [0.4939, 0.4879, 0.5032, 0.5120, 0.4849, 0.4848, 0.4895, 0.5116, 0.4892,
#          0.5006],
#         [0.4913, 0.5258, 0.5004, 0.4876, 0.4842, 0.4929, 0.5070, 0.4958, 0.4975,
#          0.4857],
#         [0.5723, 0.4958, 0.4758, 0.4981, 0.5029, 0.4845, 0.4874, 0.4843, 0.5005,
#          0.5023],
#         [0.5165, 0.4855, 0.5675, 0.4715, 0.5011, 0.4719, 0.4930, 0.4932, 0.4882,
#          0.5112],
#         [0.4978, 0.4956, 0.4929, 0.4836, 0.4954, 0.4935, 0.4956, 0.4993, 0.4930,
#          0.4935],
#         [0.4734, 0.4838, 0.4825, 0.4638, 0.4858, 0.4563, 0.4904, 0.8350, 0.4718,
#          0.4776],
#         [0.4898, 0.4978, 0.4975, 0.5443, 0.4873, 0.4891, 0.5033, 0.4917, 0.4911,
#          0.4872],
#         [0.4905, 0.5009, 0.4864, 0.4828, 0.4881, 0.4951, 0.5025, 0.4905, 0.5747,
#          0.4944],
#         [0.5043, 0.7554, 0.4926, 0.5013, 0.4742, 0.4878, 0.4906, 0.4823, 0.4688,
#          0.4846],
#         [0.5120, 0.4895, 0.5179, 0.4899, 0.5008, 0.4923, 0.4860, 0.4870, 0.5060,
#          0.4881],
#         [0.5883, 0.4885, 0.4912, 0.4865, 0.4980, 0.4850, 0.4894, 0.4863, 0.5880,
#          0.4789],
#         [0.4862, 0.4880, 0.4582, 0.4562, 0.4825, 0.7890, 0.4879, 0.4960, 0.4905,
#          0.4895],
#         [0.4898, 0.5336, 0.4875, 0.5430, 0.5127, 0.4926, 0.4874, 0.4910, 0.4864,
#          0.4918],
#         [0.4983, 0.4742, 0.7195, 0.4980, 0.5764, 0.4520, 0.4729, 0.4479, 0.4944,
#          0.4801],
#         [0.5385, 0.4859, 0.4924, 0.4929, 0.5182, 0.4882, 0.4906, 0.4976, 0.4956,
#          0.4886],
#         [0.4840, 0.5005, 0.4922, 0.4918, 0.4963, 0.5284, 0.4821, 0.4949, 0.4871,
#          0.5715],
#         [0.4936, 0.5217, 0.4885, 0.4929, 0.4864, 0.4911, 0.5306, 0.4948, 0.4864,
#          0.4925],
#         [0.4907, 0.5207, 0.4996, 0.4830, 0.5178, 0.5002, 0.4870, 0.4918, 0.4905,
#          0.4923],
#         [0.4969, 0.5028, 0.5054, 0.4738, 0.4990, 0.4891, 0.4993, 0.4944, 0.4986,
#          0.4839],
#         [0.4928, 0.4951, 0.4892, 0.4931, 0.4957, 0.4906, 0.4871, 0.4957, 0.4951,
#          0.5664],
#         [0.8495, 0.4822, 0.4986, 0.4630, 0.4767, 0.4537, 0.4781, 0.4939, 0.4654,
#          0.4593],
#         [0.5008, 0.6065, 0.4809, 0.4819, 0.4923, 0.4891, 0.4894, 0.4878, 0.5494,
#          0.5027],
#         [0.4880, 0.4559, 0.4777, 0.4886, 0.4839, 0.4933, 0.4828, 0.4893, 0.7329,
#          0.5345],
#         [0.4934, 0.6195, 0.4883, 0.5024, 0.4885, 0.4854, 0.4898, 0.4904, 0.5219,
#          0.4867],
#         [0.5740, 0.4854, 0.4808, 0.4913, 0.4846, 0.5037, 0.4970, 0.5041, 0.4906,
#          0.4863],
#         [0.4832, 0.4443, 0.4822, 0.4845, 0.4696, 0.4757, 0.5225, 0.4794, 0.4798,
#          0.8171],
#         [0.4964, 0.4934, 0.4898, 0.4944, 0.4899, 0.4941, 0.4923, 0.5318, 0.4936,
#          0.4930],
#         [0.5169, 0.4895, 0.4957, 0.4883, 0.4938, 0.4898, 0.4928, 0.5006, 0.4873,
#          0.5000],
#         [0.4525, 0.4778, 0.7439, 0.4606, 0.5393, 0.5149, 0.5416, 0.4738, 0.4655,
#          0.4865],
#         [0.4741, 0.4699, 0.4804, 0.5023, 0.4857, 0.4864, 0.4926, 0.4867, 0.7716,
#          0.4789],
#         [0.4921, 0.4928, 0.4973, 0.4901, 0.5127, 0.4863, 0.4926, 0.4999, 0.4926,
#          0.4948],
#         [0.4957, 0.4911, 0.4933, 0.4879, 0.5353, 0.5009, 0.4917, 0.4914, 0.4895,
#          0.4945],
#         [0.4836, 0.4877, 0.6158, 0.4853, 0.4877, 0.4854, 0.4778, 0.5405, 0.4926,
#          0.4896],
#         [0.5192, 0.4820, 0.4737, 0.5043, 0.4756, 0.6680, 0.4939, 0.4867, 0.4819,
#          0.4856],
#         [0.4906, 0.4920, 0.4962, 0.4852, 0.4858, 0.4923, 0.4986, 0.4948, 0.5592,
#          0.5022],
#         [0.4760, 0.5504, 0.4980, 0.5205, 0.4913, 0.4763, 0.4923, 0.4931, 0.5979,
#          0.4699],
#         [0.4965, 0.4911, 0.4964, 0.4952, 0.4863, 0.4918, 0.5141, 0.4926, 0.4955,
#          0.4954],
#         [0.4939, 0.4932, 0.5144, 0.4753, 0.4777, 0.5525, 0.5005, 0.4944, 0.4915,
#          0.4912],
#         [0.4895, 0.4982, 0.5050, 0.4875, 0.4956, 0.4810, 0.4910, 0.5194, 0.4961,
#          0.4912],
#         [0.4938, 0.4853, 0.5246, 0.4945, 0.4899, 0.4836, 0.4903, 0.4952, 0.4934,
#          0.5519],
#         [0.5519, 0.4776, 0.4736, 0.4982, 0.4913, 0.4817, 0.4927, 0.4877, 0.4695,
#          0.6809],
#         [0.4811, 0.4763, 0.4564, 0.8315, 0.4589, 0.4764, 0.5001, 0.4951, 0.4736,
#          0.4898],
#         [0.4898, 0.4817, 0.4864, 0.5452, 0.4824, 0.4772, 0.5227, 0.4995, 0.4998,
#          0.5215],
#         [0.4897, 0.4920, 0.5636, 0.4941, 0.4861, 0.4620, 0.5207, 0.5367, 0.4858,
#          0.4846],
#         [0.5065, 0.4630, 0.5084, 0.7810, 0.4719, 0.4386, 0.4756, 0.4966, 0.4721,
#          0.4726],
#         [0.4930, 0.5220, 0.4939, 0.4903, 0.4939, 0.4879, 0.4904, 0.5001, 0.4880,
#          0.5056],
#         [0.4927, 0.4950, 0.5415, 0.4961, 0.4905, 0.4831, 0.4927, 0.4959, 0.4882,
#          0.4962],
#         [0.4955, 0.4841, 0.5539, 0.4969, 0.4876, 0.4839, 0.4881, 0.4950, 0.5036,
#          0.4935],
#         [0.4904, 0.4877, 0.4888, 0.4983, 0.4962, 0.5652, 0.4891, 0.5372, 0.4877,
#          0.4873],
#         [0.4878, 0.4988, 0.4829, 0.5040, 0.5014, 0.5802, 0.4876, 0.4871, 0.4868,
#          0.4976]], device='cuda:0', grad_fn=<SigmoidBackward>)
